# %% [markdown]
# #Now this file for me not for project. Here i am only write that things so that i can relate easly to the project and
# can understand what is  going on in this project.
# 1. Here I will focous on eda , what types of plot is used for which work or exploring and extra extra.
# 2. And how to write a perfect code line for project .
# 3. I am going to start with loading csv file date that step is called data injection.
# further markdown will near to the code cell where i will stuck in code line and where i do not what is this,,,,

# %%
# first i import the library for doing work on data
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
plt.figure(figsize=(6,4))

# %%
#Here I am loading the data means injection the data with the help of read_csv
df=pd.read_csv(r"D:\machine learning projects and algoritms\linear regression\notebook\data\diamonds.csv")

# Here r is used for read the file otherwise it gives an error

# %%
# to show the data can use head(),tail(),and sample() and in which we can gives numbers to how many numbers we want to see
# if we did not provide any number is function to show then it default gives 5 records of data.
# if code all thes functions in one single line then it will show the recods the data according the sampel function .
# that means how many numbers of sample you want to retrevie if not give then default will be 1.
print("this data is with head() funtion")
df.head(5)
df.tail(5)
df.sample(10)
# Out:
# this data is with head() funtion
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 27570       27571   2.09  Very Good     H     SI1   61.1   56.0  18392  8.23
# 23606       23607   2.01    Premium     H     SI2   61.5   59.0  11635  8.12
# 45629       45630   0.40      Ideal     D    VVS2   61.2   56.0   1693  4.76
# 16707       16708   0.30       Good     H     SI1   63.4   58.0    421  4.26
# 25476       25477   1.85      Ideal     I    VVS2   62.4   57.0  14245  7.91
# 12650       12651   1.22      Ideal     G     SI2   62.3   57.0   5296  6.85
# 47091       47092   0.51      Ideal     G    VVS2   62.5   59.0   1825  5.08
# 29066       29067   0.40       Good     F     SI1   63.1   58.0    687  4.66
# 1250         1251   0.72      Ideal     H    VVS1   62.5   57.0   2946  5.70
# 19446       19447   1.53       Good     I     SI1   63.1   57.0   8095  7.28
#
#           y     z
# 27570  8.30  5.05
# 23606  8.08  4.98
# 45629  4.78  2.92
# ...

# %%
df.head()
# Out:
#    Unnamed: 0  carat      cut color clarity  depth  table  price     x     y  \
# 0           1   0.23    Ideal     E     SI2   61.5   55.0    326  3.95  3.98
# 1           2   0.21  Premium     E     SI1   59.8   61.0    326  3.89  3.84
# 2           3   0.23     Good     E     VS1   56.9   65.0    327  4.05  4.07
# 3           4   0.29  Premium     I     VS2   62.4   58.0    334  4.20  4.23
# 4           5   0.31     Good     J     SI2   63.3   58.0    335  4.34  4.35
#
#       z
# 0  2.43
# 1  2.31
# 2  2.31
# 3  2.63
# 4  2.75

# %%
df.tail()
# Out:
#        Unnamed: 0  carat        cut color clarity  depth  table  price     x  \
# 53935       53936   0.72      Ideal     D     SI1   60.8   57.0   2757  5.75
# 53936       53937   0.72       Good     D     SI1   63.1   55.0   2757  5.69
# 53937       53938   0.70  Very Good     D     SI1   62.8   60.0   2757  5.66
# 53938       53939   0.86    Premium     H     SI2   61.0   58.0   2757  6.15
# 53939       53940   0.75      Ideal     D     SI2   62.2   55.0   2757  5.83
#
#           y     z
# 53935  5.76  3.50
# 53936  5.75  3.61
# 53937  5.68  3.56
# 53938  6.12  3.74
# 53939  5.87  3.64

# %% [markdown]
# # can we use the for loop for print all functions lets try.
# lists=["head()","tail()","sample()"]
# for a in lists:
#     print(a)
#     df.a
# # No, I am unable to do that things.

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 53940 entries, 0 to 53939
# Data columns (total 11 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   Unnamed: 0  53940 non-null  int64
#  1   carat       53940 non-null  float64
#  2   cut         53940 non-null  object
#  3   color       53940 non-null  object
#  4   clarity     53940 non-null  object
#  5   depth       53940 non-null  float64
#  6   table       53940 non-null  float64
#  7   price       53940 non-null  int64
#  8   x           53940 non-null  float64
#  9   y           53940 non-null  float64
#  10  z           53940 non-null  float64
# dtypes: float64(6), int64(2), object(3)
# memory usage: 4.5+ MB

# %% [markdown]
# df.info()
# it is used for getting the information about data, like what it have columns, and size and count and data types and as like othere things,,,,

# %%
df.describe()
# Out:
#          Unnamed: 0         carat         depth         table         price  \
# count  53940.000000  53940.000000  53940.000000  53940.000000  53940.000000
# mean   26970.500000      0.797940     61.749405     57.457184   3932.799722
# std    15571.281097      0.474011      1.432621      2.234491   3989.439738
# min        1.000000      0.200000     43.000000     43.000000    326.000000
# 25%    13485.750000      0.400000     61.000000     56.000000    950.000000
# 50%    26970.500000      0.700000     61.800000     57.000000   2401.000000
# 75%    40455.250000      1.040000     62.500000     59.000000   5324.250000
# max    53940.000000      5.010000     79.000000     95.000000  18823.000000
#
#                   x             y             z
# count  53940.000000  53940.000000  53940.000000
# mean       5.731157      5.734526      3.538734
# std        1.121761      1.142135      0.705699
# min        0.000000      0.000000      0.000000
# ...

# %% [markdown]
# df.describe()
#   this function is used for describe the data , like what is the count,mean ,standard devision, min man ,25%, and many more like things.....

# %%
# i will the drop the columns that is not necessary in this table, and in this table that column is Unnamed: 0
 # for that i drop function to delete that..
df.drop("Unnamed: 0",axis=1,inplace=True)

# %%
df.sample()
# i deleted the that specific column
# Out:
#        carat      cut color clarity  depth  table  price     x     y     z
# 39919   0.41  Premium     D    VVS2   61.9   59.0   1105  4.75  4.78  2.95

# %% [markdown]
# # Now i divide the columns based on numerical and categorical data and stored into another variabel and then i will try to explore with eda features.

# %%
categorical_data=df.columns[df.dtypes=="object"]

# %%
categorical_data
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
numberical_data=df.columns[df.dtypes !=object]

# %%
numberical_data
# Out:
# Index(['carat', 'depth', 'table', 'price', 'x', 'y', 'z'], dtype='object')

# %% [markdown]
# Now i will use value_count() ,it is used to count the total numbers  with respect to its features...
# lets try value_count() function,,
# here is some tips of using the value_counts() function:
#  1.we generally did not use with that numberical data which has almost data is unique..
#  if we use it then it gives  a lot of data lists, which is almost useless..
#
# so i am not  using it with numerical data variables and numerical data columns..

# %%
df[numberical_data]["carat"].value_counts()
# Out:
# carat
# 0.30    2604
# 0.31    2249
# 1.01    2242
# 0.70    1981
# 0.32    1840
#         ...
# 3.02       1
# 3.65       1
# 3.50       1
# 3.22       1
# 3.11       1
# Name: count, Length: 273, dtype: int64

# %%
df[categorical_data]["cut"].value_counts()
df[categorical_data]["clarity"].value_counts()
df[categorical_data]["color"].value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %% [markdown]
# why it show only last line out ,why not show all output of all commands syntax ,,
# now i am try with for loop for getting output..

# %%
for a in categorical_data:
    df[categorical_data][a].value_counts()


# it does not show any things .. why i does not know .

# %%
# Now try individualy 
df[categorical_data]["cut"].value_counts()
# Out:
# cut
# Ideal        21551
# Premium      13791
# Very Good    12082
# Good          4906
# Fair          1610
# Name: count, dtype: int64

# %%
df[categorical_data]["clarity"].value_counts()
# Out:
# clarity
# SI1     13065
# VS2     12258
# SI2      9194
# VS1      8171
# VVS2     5066
# VVS1     3655
# IF       1790
# I1        741
# Name: count, dtype: int64

# %%
df[categorical_data]["color"].value_counts()
# Out:
# color
# G    11292
# E     9797
# F     9542
# H     8304
# D     6775
# I     5422
# J     2808
# Name: count, dtype: int64

# %%
# now i am plot the graph for eda with the help of for loop for categorical data 
for a in categorical_data:
    print(a)
    sns.histplot(data=df,x=a)
    print("/n")
    plt.show()
# Out:
# cut
# /n
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# color
# /n
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# clarity
# /n

# %%
from IPython.display import Image

# %%
url1_for_cut=""
url2_for_color=""
url3_for_clarity="https://cdn.shopify.com/s/files/1/0160/7666/files/Diamond-Clarity-Chart-11.jpg?v=1646277625"

# %%
Image(url=url3_for_clarity)
# Out:
# <img src="https://cdn.shopify.com/s/files/1/0160/7666/files/Diamond-Clarity-Chart-11.jpg?v=1646277625"/>

# %%
# I am using numberical_data columns to plot histogram graph , it basically use to know, which type of distribution data it has exists.
for col in numberical_data:
    print(col)
    sns.histplot(data=df,x=col,kde=True)
    print("/n")
    plt.show()
# Out:
# carat
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /n
# depth
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /n
# table
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# /n
# price
# ...

# %%
sns.barplot(data=df,x=df["x"])
# Out:
# <Axes: xlabel='x'>

# %%
sns.pairplot(data=df)
print("/n")
plt.show()
# Out:
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.heatmap(df[numberical_data].corr())
# Out:
# <Axes: >

# %%
#df.corr()

# %%
sns.jointplot(data=df,x="carat",y="price",kind="scatter")
# Out:
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):

# %%
sns.pairplot(df,hue="cut")
# Out:
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\_oldcore.py:1119: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
sns.countplot(data=df,x="cut")
# Out:
# <Axes: xlabel='cut', ylabel='count'>

# %%
sns.boxenplot(data=df,palette="rainbow")
# Out:
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# c:\Users\ankit\anaconda3\Lib\site-packages\seaborn\categorical.py:1794: FutureWarning: use_inf_as_na option is deprecated and will be removed in a future version. Convert inf values to NaN before operating instead.
#   with pd.option_context('mode.use_inf_as_na', True):
# ...

# %%
df[numberical_data].corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
sns.heatmap(df[numberical_data].corr(),annot=True)
# Out:
# <Axes: >

# %%
df[numberical_data].corr()
# Out:
#           carat     depth     table     price         x         y         z
# carat  1.000000  0.028224  0.181618  0.921591  0.975094  0.951722  0.953387
# depth  0.028224  1.000000 -0.295779 -0.010647 -0.025289 -0.029341  0.094924
# table  0.181618 -0.295779  1.000000  0.127134  0.195344  0.183760  0.150929
# price  0.921591 -0.010647  0.127134  1.000000  0.884435  0.865421  0.861249
# x      0.975094 -0.025289  0.195344  0.884435  1.000000  0.974701  0.970772
# y      0.951722 -0.029341  0.183760  0.865421  0.974701  1.000000  0.952006
# z      0.953387  0.094924  0.150929  0.861249  0.970772  0.952006  1.000000

# %%
df.select_dtypes(include="object").columns
# Out:
# Index(['cut', 'color', 'clarity'], dtype='object')

# %%
df["cut"].unique()
# Out:
# array(['Ideal', 'Premium', 'Good', 'Very Good', 'Fair'], dtype=object)

# %%
df["color"].unique()
# Out:
# array(['E', 'I', 'J', 'H', 'F', 'G', 'D'], dtype=object)

# %%
df["clarity"].unique()
# Out:
# array(['SI2', 'SI1', 'VS1', 'VS2', 'VVS2', 'VVS1', 'I1', 'IF'],
#       dtype=object)

# %%
cut_map={"Fair":1,"Ideal":5,"Good":2,"Very Good":3,"Premium":4}
clarity_map={"I1":1,"SI2":2,"SI1":3,"VS2":4,"VS1":5,"VVS2":6,"VVS1":7,"IF":8}
color_map={"D":1,"E":2,"F":3,"G":4,"H":5,"I":6,"J":7}

# %%
df["cut"]=df["cut"].map(cut_map)
df["clarity"]=df["clarity"].map(clarity_map)
df["color"]=df["color"].map(color_map)

# %%
df.head()
# Out:
#    carat  cut  color  clarity  depth  table  price     x     y     z
# 0   0.23    5      2        2   61.5   55.0    326  3.95  3.98  2.43
# 1   0.21    4      2        3   59.8   61.0    326  3.89  3.84  2.31
# 2   0.23    2      2        5   56.9   65.0    327  4.05  4.07  2.31
# 3   0.29    4      6        4   62.4   58.0    334  4.20  4.23  2.63
# 4   0.31    2      7        2   63.3   58.0    335  4.34  4.35  2.75
